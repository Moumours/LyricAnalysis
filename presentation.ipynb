# %% [markdown]
# # Lyric Analysis

# %% [markdown]
# ## Initialisation

# %%
from scripts_python.gen_Spotify import SpotifyData
from scripts_python.graphs import Graph

# %%
spotify_data = SpotifyData()
if spotify_data.sp:
    graph = Graph(spotify_data)
    
    spotify_data.get_user_data()
    spotify_data.load_spotify_favorite_songs()
    # lyrics_utils.initialize_lyrics()
# Out:
# Data successfully loaded

# %% [markdown]
# ## Graphs

# %%
artist_name = "100 Gecs"

graph.draw_lyrics_from_one_singer(artist_name, True)

# %%
artist_name = "100 Gecs"
song_name = "xXXi_wud_nvrstøp_ÜXXx"

graph.draw_lyrics_from_one_song(artist_name, song_name, True)

# %%
artist_name = "100 Gecs"
song_name = "xXXi_wud_nvrstøp_ÜXXx"

graph.print_sentiment_from_one_song(artist_name, song_name)
# Out:
# 67 ContributorsTranslationsУкраїнськаEspañolPolskiTürkçeРусский​xXXi_wud_nvrstøp_ÜXXx Lyrics[Intro: Laura Les]. 0.0 0.0
# Baby, you know that I got ya. 0.0 0.0
# I would never stop you. 0.0 0.0
# I would never stop you. 0.0 0.0
# 'Cause you know I'm crazy. -0.6 0.9
# Crazy for you, baby. -0.6 0.9
# And you gotta know. 0.0 0.0
# Every day you've got me oh, feeling like. 0.0 0.0
# . 0.0 0.0
# [Chorus: Laura Les]. 0.0 0.0
# Baby, you know that I got ya. 0.0 0.0
# I could never stop you. 0.0 0.0
# I would never stop you. 0.0 0.0
# 'Cause you know I'm crazy. -0.6 0.9
# Crazy for you, baby. -0.6 0.9
# And you gotta know. 0.0 0.0
# Every day, you got me oh, feeling like. 0.0 0.0
# Baby, you know that I got ya. 0.0 0.0
# I would never stop you. 0.0 0.0
# I would never stop you. 0.0 0.0
# 'Cause you know I'm crazy. -0.6 0.9
# Crazy for you, baby. -0.6 0.9
# And you gotta know. 0.0 0.0
# Every day, you got me always feeling like. 0.0 0.0
# Baby, you know that I got ya. 0.0 0.0
# I would never stop you. 0.0 0.0
# I would never stop you. 0.0 0.0
# 'Cause you know I'm crazy. -0.6 0.9
# Crazy for you, baby. -0.6 0.9
# And you gotta know. 0.0 0.0
# Every day, you got me always feeling like. 0.0 0.0
# You might also like[Break: Laura Les]. 0.0 0.0
# I would never stop you. 0.0 0.0
# . 0.0 0.0
# [Verse: Dylan Brady]. 0.0 0.0
# Giving my heart for you to take. 0.0 0.0
# We could go and drive and leave this place. 0.0 0.0
# Getting my strength from your embrace. 0.0 0.0
# Baby, let's go all the way. 0.0 0.0
# Giving my heart for you to take. 0.0 0.0
# We could go and drive and leave this place. 0.0 0.0
# Getting my strength from your embrace. 0.0 0.0
# Baby, let's go all the way. 0.0 0.0
# . 0.0 0.0
# [Chorus: Laura Les]. 0.0 0.0
# Baby, you know that I got ya. 0.0 0.0
# I would never stop you. 0.0 0.0
# I would never stop you. 0.0 0.0
# 'Cause you know I'm crazy. -0.6 0.9
# Crazy for you, baby. -0.6 0.9
# And you gotta know. 0.0 0.0
# Every day, you got me always feeling like. 0.0 0.0
# Baby, you know that I got ya. 0.0 0.0
# I would never stop you. 0.0 0.0
# I would never stop you. 0.0 0.0
# 'Cause you know I'm crazy. -0.6 0.9
# Crazy for you, baby. -0.6 0.9
# And you gotta know. 0.0 0.0
# Every day, you got me always feeling like. 0.0 0.0
# [Outro]. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# (Wait a minute now). 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay, bay, bay, bay, bay, bay. 0.0 0.0
# Bay, bay, bay. 0.0 0.0
# Bay-bay-bay, bay, bay. 0.0 0.0
# Bay-bay-bay, bay, bay. 0.0 0.0
# Bay-bay-bay, bay, bay. 0.0 0.0
# Bay-bay-bay7Embed 0.0 0.0
