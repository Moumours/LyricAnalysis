# %% [markdown]
# # Lyric Analysis

# %% [markdown]
# ## Initialisation

# %%
from scripts_python.gen_Spotify import SpotifyData
from scripts_python.graphs import Graph

# %%
spotify_data = SpotifyData()
if spotify_data.sp:
    graph = Graph(spotify_data)
    
    spotify_data.get_user_data()
    spotify_data.load_spotify_favorite_songs()
    # lyrics_utils.initialize_lyrics()
# Out:
# Data successfully loaded

# %% [markdown]
# ## Graphs

# %%
artist_name = "100 Gecs"

graph.draw_lyrics_from_one_singer(artist_name, True)

# %%
artist_name = "100 Gecs"
song_name = "Stupid Horse"

graph.draw_lyrics_from_one_song(artist_name, song_name, True)

# %%
artist_name = "100 Gecs"
song_name = "Stupid Horse"

graph.print_sentiment_from_one_song(artist_name, song_name)
# Out:
# 81 ContributorsTranslationsРусскийTürkçeУкраїнськаEspañolPolski​stupid horse Lyrics[Intro]. 0.0 0.0
# Pick it up!. 0.0 0.0
# . 0.0 0.0
# [Verse 1: Laura Les]. 0.0 0.0
# Bet my money on a stupid horse, I lost that. -0.7999999999999999 1.0
# So I ran out to the track to get my cash back. 0.0 0.0
# I just gotta leave this place with a big bag. 0.0 0.1
# So I found the fuckin' jockey and I grabbed that (Pick it up!). 0.0 0.0
# Pushed him down to the ground and I punched him in his face (In his face!). -0.19444444444444448 0.2888888888888889
# Yeah, I stole his phone, that put him in his place (In his place!). 0.0 0.0
# Me and the horse, we ran out of the place (Out the place!). 0.0 0.0
# Then we drove my Porsche back to my place. 0.0 0.0
# . 0.0 0.0
# [Chorus: Laura Les]. 0.0 0.0
# Stupid horse, I just fell out of the Porsche. -0.7999999999999999 1.0
# Lost the money in my bank account, oh no. 0.0 0.0
# Stupid horse, I just fell out of the Porsche. -0.7999999999999999 1.0
# ...

# %%
# singers_names = ["all"]
singers_names = ["Rihanna", "BlackPink", "100 Gecs", "Eminem"]

graph.plot_sentiment_scores(singers_names)
